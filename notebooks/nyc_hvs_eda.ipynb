# %%
# %load_ext autoreload
# %autoreload 2
# %cd ..
# Out:
# /home/daniel/Documents/housing

# %%
import pathlib
import pandas as pd
import os

root_path = pathlib.Path(".")
data_path = root_path / "data"
hvs_data_path = data_path / "NYC_HVS"
year = 2023
year_data_path = hvs_data_path / str(year)

files = os.listdir(year_data_path)

dfs = {}
for file in files:
    if file.endswith(".csv"):
        dfs[file.replace(".csv", "")] = (pd.read_csv(year_data_path / file))

# %%
dfs["occupied_puf_23"]["RENT_AMOUNT"].describe()
# Out:
# count     8776.000000
# mean      1396.629900
# std       1502.500787
# min         -2.000000
# 25%          0.000000
# 50%       1200.000000
# 75%       1975.000000
# max      12495.000000
# Name: RENT_AMOUNT, dtype: float64

# %%
dfs["occupied_puf_23"]
# Out:
#        CONTROL  TENURE  HHSIZE  HH62PLUS  HHUNDER18  HHUNDER6  HHFIRSTMOVEIN
# 0     12130002       2       4         2          1         2           2007  \
# 1     12130005       1       2         1          2         2           2003
# 2     12130008       1       2         2          2         2           2022
# 3     12130010       1       1         2          2         2           2021
# 4     12130011       2       1         2          2         2           2021
# ...        ...     ...     ...       ...        ...       ...            ...
# 8771  12158886       1       2         1          2         2           2013
# 8772  12158888       1       3         2          1         2           2018
# 8773  12158891       2       5         2          1         2           2007
# 8774  12158893       1       2         2          2         2           2022
# 8775  12158897       1       1         1          2         2           2012
#
# ...

# %%
dfs["allunits_puf_23"]
# Out:
#        CONTROL  BORO  OCC  CSR  CONDOCOOP  STORIES  ELEVATOR  UNITS
# 0     12130002     2    1    2          2        6         1     10  \
# 1     12130005     3    1   80          2        4         1      6
# 2     12130008     3    1   80          3        7         1     10
# 3     12130010     3    1   80          3        5         1     10
# 4     12130011     3    1    2          2        4         1      8
# ...        ...   ...  ...  ...        ...      ...       ...    ...
# 9592  12158886     1    1   32          3        5         1      9
# 9593  12158888     2    1   80          3        1         2      2
# 9594  12158891     5    1    6          3        1         2      2
# 9595  12158893     3    1   80          3        7         1     10
# 9596  12158897     1    1   32          3        5         1     10
#
#       UNIT_FLOOR  UNIT_ONEPLUSFLIGHT  ...         FW71        FW72
# 0              5                   2  ...   442.455446  127.631770  \
# ...
