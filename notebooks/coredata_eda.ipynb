# %%
# %load_ext autoreload
# %autoreload 2
# %cd ..
# Out:
# /home/daniel/Documents/housing

# %%
import pathlib
import pandas as pd
import seaborn as sns
import os

root_path = pathlib.Path(".")
data_path = root_path / "data"
coredata_data_path = data_path / "COREDATA"

data = pd.read_csv(coredata_data_path / "bbl_level_data.csv")
# Out:
# /tmp/ipykernel_711751/3185240179.py:10: DtypeWarning: Columns (103,106,118) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(coredata_data_path / "bbl_level_data.csv")

# %%
sns.scatterplot(data=data, x="longitude", y="latitude", hue="boro_name", s=2)
# Out:
# <Axes: xlabel='longitude', ylabel='latitude'>

# %%
data.columns[]
# Out:
# Index(['bbl', 'standard_address', 'city_id', 'city_name', 'boro_id',
#        'boro_name', 'cd_id', 'cd_name', 'sba_id', 'sba_name',
#        ...
#        'end_proj8', 'prog_rad', 'start_rad', 'end_rad', 'prog_tpt',
#        'start_tpt', 'end_tpt', 'prog_year15', 'start_year15', 'end_year15'],
#       dtype='object', length=126)

# %%
dfs["allunits_puf_23"]
# Out:
#        CONTROL  BORO  OCC  CSR  CONDOCOOP  STORIES  ELEVATOR  UNITS
# 0     12130002     2    1    2          2        6         1     10  \
# 1     12130005     3    1   80          2        4         1      6
# 2     12130008     3    1   80          3        7         1     10
# 3     12130010     3    1   80          3        5         1     10
# 4     12130011     3    1    2          2        4         1      8
# ...        ...   ...  ...  ...        ...      ...       ...    ...
# 9592  12158886     1    1   32          3        5         1      9
# 9593  12158888     2    1   80          3        1         2      2
# 9594  12158891     5    1    6          3        1         2      2
# 9595  12158893     3    1   80          3        7         1     10
# 9596  12158897     1    1   32          3        5         1     10
#
#       UNIT_FLOOR  UNIT_ONEPLUSFLIGHT  ...         FW71        FW72
# 0              5                   2  ...   442.455446  127.631770  \
# ...
